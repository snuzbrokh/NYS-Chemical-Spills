# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
storage = pd.read_csv("../data/storage_clean.csv")

# %%
import pyproj

# %%
myProj = Proj("+proj=utm +zone=18K, +north +ellps=WGS84 +datum=WGS84 +units=m +no_defs")

# %%
lon, lat = myProj(storage['UTMX'].values, storage['UTMY'].values)

# %%
u = utm.from_latlon(47.9941214, 7.8509671)
u
# Out:
# (414278.16730997514, 5316285.595228155, 32, 'T')

# %%
print(utm.to_latlon(*u))
# Out:
# (47.994121400319436, 7.850967021791838)

# %%
p = pyproj.Proj(proj='utm', zone=18, ellps='WGS84')

# %%
lon, lat = p(storage['UTMX'].values, storage['UTMY'].values, inverse=True)

# %%
lon
# Out:
# array([-73.89617642, -77.66424701, -73.6623237 , ..., -78.79280047,
#        -78.79280047, -78.79280047])

# %%
# Out:
# Index(['X1', 'Program.Number', 'Program.Type', 'Site.Type.Name',
#        'Program.Facility.Name', 'Address.1', 'Locality', 'ZIP.Code',
#        'NYSDEC.Region', 'Tank.Number', 'Tank.Location', 'Tank.Status',
#        'Install.Date', 'Capacity.in.Gallons', 'Tank.Type', 'Close.Date',
#        'Material.Name', 'Percent', 'Expiration.Date', 'Site.Status.Name',
#        'Lon', 'Lat', 'County.FIPS', 'County.Name'],
#       dtype='object')

# %%
storage.to_csv('storage_clean.csv')

# %%
storage[['Address 1', 'Locality', 'ZIP Code',
       'NYSDEC Region', 'Tank Number', 'Tank Location', 'Tank Status',
       'Install Date', 'Capacity in Gallons', 'Tank Type', 'Close Date',
       'Material Name', 'Percent', 'Expiration Date', 'Site Status Name']].sample()
# Out:
#                                         Address 1  Locality  ZIP Code  \
# 282574  5908 HORSESHOE LAKE ROAD                   STAFFORD     14143
#
#         NYSDEC Region Tank Number  \
# 282574              8        001B
#
#                                             Tank Location  \
# 282574  Aboveground on saddles, legs, stilts, rack or ...
#
#                                 Tank Status             Install Date  \
# 282574  Tank Converted to Non-Regulated use  1992-02-01T00:00:00.000
#
#         Capacity in Gallons                Tank Type Close Date Material Name  \
# 282574               1000.0  Steel/Carbon Steel/Iron        NaN        diesel
#
#         Percent          Expiration Date    Site Status Name
# 282574    100.0  2012-10-06T00:00:00.000  Unregulated/Closed

# %%
col = 'UTMX'

# %%
storage[col].sort_values().unique()
# Out:
# array([       0.     ,   106866.54831,   107593.43437, ...,
#          759819.69994, 11245017.72941,            nan])

# %%
sum(storage[col].isna())
# Out:
# 8881

# %%
sum(storage['Percent']==0)
# Out:
# 41744

# %%
storage[storage[col].isna()][['Site Type Name','Tank Number', 'Tank Location', 'Tank Status',
       'Install Date', 'Capacity in Gallons', 'Tank Type', 'Close Date',
       'Material Name', 'Percent', 'Expiration Date', 'Site Status Name']]
# Out:
#                                            Site Type Name Tank Number  \
# 1       Municipality (Incl. Waste Water Treatment Plan...         NaN
# 2       Municipality (Incl. Waste Water Treatment Plan...         NaN
# 3                          Utility (Other than Municipal)         NaN
# 4       Municipality (Incl. Waste Water Treatment Plan...         NaN
# 5       Municipality (Incl. Waste Water Treatment Plan...         NaN
# ...                                                   ...         ...
# 327320             Storage Terminal/Petroleum Distributor         NaN
# 327346             Storage Terminal/Petroleum Distributor         NaN
# 327349             Storage Terminal/Petroleum Distributor         NaN
# 327354             Storage Terminal/Petroleum Distributor         NaN
# 327366             Storage Terminal/Petroleum Distributor         NaN
#
#        Tank Location Tank Status Install Date  Capacity in Gallons Tank Type  \
# 1                  ?           ?          NaN                  0.0         ?
# 2                  ?           ?          NaN                  0.0         ?
# 3                  ?           ?          NaN                  0.0         ?
# 4                  ?           ?          NaN                  0.0         ?
# 5                  ?           ?          NaN                  0.0         ?
# ...              ...         ...          ...                  ...       ...
# 327320             ?           ?          NaN                  0.0         ?
# 327346             ?           ?          NaN                  0.0         ?
# 327349             ?           ?          NaN                  0.0         ?
# 327354             ?           ?          NaN                  0.0         ?
# 327366             ?           ?          NaN                  0.0         ?
#
#        Close Date Material Name  Percent Expiration Date Site Status Name
# 1                             ?      0.0                           Active
# 2                             ?      0.0                           Active
# 3                             ?      0.0                           Active
# 4                             ?      0.0                           Active
# 5                             ?      0.0                           Active
# ...           ...           ...      ...             ...              ...
# 327320                        ?      0.0                           Active
# 327346                        ?      0.0                           Active
# 327349                        ?      0.0                           Active
# 327354                        ?      0.0                           Active
# 327366                        ?      0.0                           Active
#
# [41691 rows x 12 columns]

# %%
storage
# Out:
#        Program Number Program Type  \
# 0            2-609057          PBS
# 1            1-000029          CBS
# 2            1-000029          CBS
# 3            1-000036          CBS
# 4            1-000094          CBS
# ...               ...          ...
# 327362       9-600875          PBS
# 327363       9-601282          PBS
# 327364       9-601426          PBS
# 327365       9-601110          PBS
# 327366       9-601791          PBS
#
#                                            Site Type Name  \
# 0                                                   Other
# 1       Municipality (Incl. Waste Water Treatment Plan...
# 2       Municipality (Incl. Waste Water Treatment Plan...
# 3                          Utility (Other than Municipal)
# 4       Municipality (Incl. Waste Water Treatment Plan...
# ...                                                   ...
# 327362                                              Other
# 327363  Municipality (Incl. Waste Water Treatment Plan...
# 327364                                              Other
# 327365                     Utility (Other than Municipal)
# 327366             Storage Terminal/Petroleum Distributor
#
#                        Program Facility Name Address 1 Address 2     Locality  \
# 0                                  CITIGROUP       NaN       NaN     New York
# 1                    NEW YORK AVE. WELLFIELD       NaN       NaN   MASSAPEQUA
# 2                    NEW YORK AVE. WELLFIELD       NaN       NaN   MASSAPEQUA
# 3       HEMPSTEAD RESOURCE RECOVERY FACILITY       NaN       NaN     Westbury
# 4                             CANTIAGUE PARK       NaN       NaN   Hicksville
# ...                                      ...       ...       ...          ...
# 327362               JOSEPH DAVIS STATE PARK       NaN       NaN     Lewiston
# 327363    NEWFANE WASTEWATER PUMP STATION #3       NaN       NaN      NEWFANE
# 327364                              PROPERTY       NaN       NaN  WEST SENECA
# 327365                   CAMBRIA RADIO TOWER       NaN       NaN     Lockport
# 327366                 NORTH BUSTI OIL FIELD       NaN       NaN    JAMESTOWN
#
#         ZIP Code      County  NYSDEC Region  ...          UTMY  \
# 0          10013    New York              2  ...  4.508213e+06
# 1          11758      Nassau              1  ...  4.504060e+06
# 2          11758      Nassau              1  ...  4.504060e+06
# 3          11590      Nassau              1  ...  4.510648e+06
# 4          11801      Nassau              1  ...  4.514455e+06
# ...          ...         ...            ...  ...           ...
# 327362     14092     Niagara              9  ...  4.791749e+06
# 327363     14108     Niagara              9  ...           NaN
# 327364     14224        Erie              9  ...  4.749104e+06
# 327365     14094     Niagara              9  ...  4.785751e+06
# 327366     14701  Chautauqua              9  ...           NaN
#
#                                                Location 1  \
# 0       {'human_address': '{"address": "388 GREENWICH ...
# 1                                                     NaN
# 2                                                     NaN
# 3       {'human_address': '{"address": "600 MERCHANTS"...
# 4                                                     NaN
# ...                                                   ...
# 327362  {'human_address': '{"address": "590 Pletcher R...
# 327363                                                NaN
# 327364  {'human_address': '{"address": "5159 SENECA ST...
# 327365  {'human_address': '{"address": "4500 UPPER MOU...
# 327366  {'human_address': '{"address": "1464 FOREST AV...
#
#        NYS Municipal Boundaries New York Zip Codes  Counties County Name  \
# 0                         749.0              737.0    2095.0    New York
# 1                           NaN                NaN       NaN     Suffolk
# 2                           NaN                NaN       NaN      Nassau
# 3                           NaN                NaN       NaN      Nassau
# 4                           NaN                NaN       NaN      Nassau
# ...                         ...                ...       ...         ...
# 327362                    164.0               31.0    2131.0     Niagara
# 327363                      NaN                NaN       NaN     Niagara
# 327364                    276.0              159.0    2041.0        Erie
# 327365                    173.0              930.0    2131.0     Niagara
# 327366                    224.0             1687.0    2035.0  Chautauqua
#
#        State FIPS County Code  County FIPS   File Date
# 0            36.0        61.0      36061.0  07/25/2007
# 1            36.0       103.0      36103.0  07/25/2007
# 2            36.0        59.0      36059.0  07/25/2007
# 3            36.0        59.0      36059.0  07/25/2007
# 4            36.0        59.0      36059.0  07/25/2007
# ...           ...         ...          ...         ...
# 327362       36.0        63.0      36063.0  07/25/2007
# 327363       36.0        63.0      36063.0  07/25/2007
# 327364       36.0        29.0      36029.0  07/25/2007
# 327365       36.0        63.0      36063.0  07/25/2007
# 327366       36.0        13.0      36013.0  07/25/2007
#
# [327367 rows x 32 columns]

# %%
storage = pd.read_csv()
